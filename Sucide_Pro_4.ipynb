# %%
# Load python Library

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler

# %%
cd C:\Users\Lenovo\Downloads
# Out:
# C:\Users\Lenovo\Downloads

# %%
# Get Data

data = pd.read_csv('master.csv')

# %%
# View Data

data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# Check unique value 

data['age'].unique()
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %%
# Check column by list 

Age=list(data['age'])

# %%
Age
# Out:
# ['15-24 years',
#  '35-54 years',
#  '15-24 years',
#  '75+ years',
#  '25-34 years',
#  '75+ years',
#  '35-54 years',
#  '25-34 years',
#  '55-74 years',
#  '5-14 years',
#  '55-74 years',
#  '5-14 years',
#  '75+ years',
#  '15-24 years',
#  '75+ years',
#  '35-54 years',
#  '55-74 years',
#  '15-24 years',
#  '55-74 years',
#  '25-34 years',
#  '25-34 years',
#  '35-54 years',
#  '5-14 years',
#  '5-14 years',
#  '75+ years',
#  '25-34 years',
#  '35-54 years',
#  '55-74 years',
#  '15-24 years',
#  '35-54 years',
#  '15-24 years',
#  '25-34 years',
#  '55-74 years',
#  '5-14 years',
#  '75+ years',
#  '5-14 years',
#  '35-54 years',
#  '15-24 years',
#  '55-74 years',
#  '25-34 years',
#  '15-24 years',
#  '25-34 years',
#  '35-54 years',
#  '55-74 years',
#  '5-14 years',
#  '75+ years',
#  '5-14 years',
#  '75+ years',
#  '15-24 years',
#  '55-74 years',
#  '75+ years',
#  '25-34 years',
#  '15-24 years',
#  '35-54 years',
#  '25-34 years',
#  '35-54 years',
#  '55-74 years',
# ...

# %%
# Spliting Age Column

minimum_age=[]
maximum_age=[]

for i in range(len(Age)):
    
    minimum_age.append(Age[i].split()[0].split(sep='-')[-1])
    maximum_age.append(Age[i].split()[0].split(sep='-')[0])

# %%
data['max_age']=maximum_age
data['min_age']=minimum_age

# %%
# Replace in column value

data= data.replace('75+ years', 76)

# %%
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male           76            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female           76            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# View data's columns & row

data.shape
# Out:
# (27820, 14)

# %%
# Check column data-type

data.dtypes
# Out:
# country                object
# year                    int64
# sex                    object
# age                    object
# suicides_no             int64
# population              int64
# suicides/100k pop     float64
# country-year           object
# HDI for year          float64
#  gdp_for_year ($)      object
# gdp_per_capita ($)      int64
# generation             object
# max_age                object
# min_age                object
# dtype: object

# %%
# check data's info like null value, data-type, data-size

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
#  12  max_age             27820 non-null  object
#  13  min_age             27820 non-null  object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 3.0+ MB

# %%
# View all data columns

data.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation', 'max_age',
#        'min_age'],
#       dtype='object')

# %%
data['age'].unique()
# Out:
# array(['15-24 years', '35-54 years', 76, '25-34 years', '55-74 years',
#        '5-14 years'], dtype=object)

# %%
# check null value in data

data.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# max_age                   0
# min_age                   0
# dtype: int64

# %%
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male   Adolescent           21      312900
# 1         Albania  1987    male  tricenurian           16      308000
# 2         Albania  1987  female   Adolescent           14      289700
# 3         Albania  1987    male           76            1       21800
# 4         Albania  1987    male        Adult            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  tricenurian          107     3620833
# 27816  Uzbekistan  2014  female           76            9      348465
# 27817  Uzbekistan  2014    male        Child           60     2762158
# 27818  Uzbekistan  2014  female        Child           44     2631600
# 27819  Uzbekistan  2014  female       Senior           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
# Delete column

data.drop(['HDI for year'],axis=1,inplace=True)

# %%
# Data's statical view

data.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        gdp_per_capita ($)
# count        27820.000000
# mean         16866.464414
# std          18887.576472
# min            251.000000
# 25%           3447.000000
# 50%           9372.000000
# 75%          24874.000000
# max         126352.000000

# %%
data.drop(['age'],axis=1,inplace=True)

# %%
data
# Out:
#           country  year     sex  suicides_no  population  suicides/100k pop  \
# 0         Albania  1987    male           21      312900               6.71
# 1         Albania  1987    male           16      308000               5.19
# 2         Albania  1987  female           14      289700               4.83
# 3         Albania  1987    male            1       21800               4.59
# 4         Albania  1987    male            9      274300               3.28
# ...           ...   ...     ...          ...         ...                ...
# 27815  Uzbekistan  2014  female          107     3620833               2.96
# 27816  Uzbekistan  2014  female            9      348465               2.58
# 27817  Uzbekistan  2014    male           60     2762158               2.17
# 27818  Uzbekistan  2014  female           44     2631600               1.67
# 27819  Uzbekistan  2014  female           21     1438935               1.46
#
# ...

# %%
# String to numeric data label-encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data = data.apply(le.fit_transform)

# %%
data
# Out:
#        country  year  sex  suicides_no  population  suicides/100k pop  \
# 0            0     2    1           21        9950                670
# 1            0     2    1           16        9835                518
# 2            0     2    0           14        9358                482
# 3            0     2    1            1        2606                458
# 4            0     2    1            9        8945                327
# ...        ...   ...  ...          ...         ...                ...
# 27815      100    29    0          107       21487                295
# 27816      100    29    0            9       10720                257
# 27817      100    29    1           60       20457                216
# 27818      100    29    0           44       20332                166
# 27819      100    29    0           21       18506                145
#
#        country-year   gdp_for_year ($)   gdp_per_capita ($)  generation  \
# ...

# %%
data.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# suicides_no           0
# population            0
# suicides/100k pop     0
# country-year          0
#  gdp_for_year ($)     0
# gdp_per_capita ($)    0
# generation            0
# max_age               0
# min_age               0
# dtype: int64

# %%
# Split data for ML model creation

X = data.drop(['suicides_no'],axis=1)
Y = data.suicides_no

# %%
Y
# Out:
# 0         21
# 1         16
# 2         14
# 3          1
# 4          9
#         ...
# 27815    107
# 27816      9
# 27817     60
# 27818     44
# 27819     21
# Name: suicides_no, Length: 27820, dtype: int64

# %%
# ML algorithm

from sklearn.ensemble import RandomForestRegressor

# %%
Rf= RandomForestRegressor()

# %%
Rf.fit(X,Y)
# Out:
# RandomForestRegressor()

# %%
# Training data Accuracy

Rf.score(X,Y)
# Out:
# 0.9999469079781073

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model=Rf.fit(X_train,Y_train)

# %%
# Testing data Accuracy

model.score(X_test,Y_test)
# Out:
# 0.9995664357424909
